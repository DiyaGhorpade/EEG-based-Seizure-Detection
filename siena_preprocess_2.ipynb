# %%
import os
import gc
import numpy as np
import mne
from mne.preprocessing import ICA, create_eog_epochs

# %%
#change paths
RAW_PATH = "/workspace/raw_dataset"
SAVE_PATH = "/workspace/preprocessed_data_2"
os.makedirs(SAVE_PATH, exist_ok=True)

# %%
CANONICAL_CHANNELS = [
    "EEG Fp1", "EEG F3", "EEG C3", "EEG P3", "EEG O1",
    "EEG F7", "EEG T3", "EEG T5",
    "EEG Fc1", "EEG Fc5",
    "EEG Cp1", "EEG Cp5",
    "EEG F9", "EEG Fz", "EEG Pz",
    "EEG F4", "EEG C4", "EEG P4", "EEG O2",
    "EEG F8", "EEG T4", "EEG T6",
    "EEG Fc2", "EEG Fc6",
    "EEG Cp2", "EEG Cp6",
    "EEG F10"
]

# %%
# Bandpass
LOW_F = 0.5
HIGH_F = 40.0

# Notch
NOTCH = 50.0

# Epoching (USED LATER, NOT HERE)
EPOCH_LEN = 5.0

# Resampling
RESAMPLE_SFREQ = 256

# Memory safety
MAX_DURATION = 600          # seconds (final output)
ICA_MAX_DURATION = 20 * 60  # seconds (ICA only)

# ICA
ICA_METHOD = "picard"
ICA_N_COMPONENTS = 0.95
ICA_RANDOM_STATE = 97

# %%
def load_edf(edf_path):
    raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
    raw.pick("eeg")

    if raw.n_times < 1:
        raise ValueError("Empty EDF")

    return raw

# %%
def preprocess_raw(raw):
    # ---- HARD MEMORY BOUND FIRST ----
    duration = raw.times[-1]
    crop_t = min(duration, ICA_MAX_DURATION)

    raw.crop(tmax=crop_t)     # crop BEFORE loading data
    raw.load_data()           # now load only cropped data

    # ---- now it's safe ----
    raw.resample(RESAMPLE_SFREQ, npad="auto")
    raw.filter(LOW_F, HIGH_F, verbose=False)
    raw.notch_filter(NOTCH, verbose=False)

    return raw

# %%
def run_ica(raw):
    raw_ica = raw.copy().filter(l_freq=1.0, h_freq=None, verbose=False)

    try:
        ica = ICA(
            n_components=ICA_N_COMPONENTS,
            method=ICA_METHOD,
            random_state=ICA_RANDOM_STATE,
            max_iter="auto"
        )

        ica.fit(raw_ica)

        if ica.n_components_ < 2:
            print("Skipping ICA (rank too low)")
            return raw

        ica.apply(raw)

    except Exception as e:
        print("ICA failed, skipping:", e)

    finally:
        del raw_ica
        gc.collect()

    return raw

# %%
def apply_final_crop(raw):
    if raw.times[-1] > MAX_DURATION:
        raw.crop(tmax=MAX_DURATION)
    return raw

# %%
def extract_data(raw):
    data = raw.get_data()
    ch_names = raw.ch_names
    sfreq = raw.info["sfreq"]
    n_times = raw.n_times
    return data, ch_names, sfreq, n_times

# %%
def read_siena_seizure_times(annotation_path):
    seizure_times = []

    with open(annotation_path, "r") as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith("#"):
                continue

            parts = line.replace(",", " ").split()
            if len(parts) < 2:
                continue

            try:
                start = float(parts[0])
                end = float(parts[1])
                seizure_times.append((start, end))
            except ValueError:
                continue

    return seizure_times

# %%
def epoch_and_label(raw, seizure_times, epoch_len=5.0):
    epochs = mne.make_fixed_length_epochs(
        raw,
        duration=epoch_len,
        preload=True
    )

    X = epochs.get_data().astype(np.float32)

    # Normalize per epoch
    mean = X.mean(axis=-1, keepdims=True)
    std = X.std(axis=-1, keepdims=True) + 1e-6
    X = (X - mean) / std

    n_epochs = len(X)
    y = np.zeros(n_epochs, dtype=np.int8)

    for i in range(n_epochs):
        start_sec = i * epoch_len
        end_sec = start_sec + epoch_len

        for s0, s1 in seizure_times:
            if end_sec > s0 and start_sec < s1:
                y[i] = 1
                break

    return X, y, epochs.info["sfreq"], epochs.ch_names

# %%
def apply_canonical_channels(data, ch_names, canonical_channels, n_times):
    ch_index = {ch.upper(): i for i, ch in enumerate(ch_names)}

    final_data = np.zeros(
        (len(canonical_channels), n_times),
        dtype=np.float32
    )

    for i, ch in enumerate(canonical_channels):
        key = ch.upper()
        if key in ch_index:
            final_data[i] = data[ch_index[key]]

    return final_data

# %%
def save_npz(save_path, X, y, sfreq, channels):
    np.savez_compressed(
        save_path,
        data=X,
        labels=y,
        sfreq=sfreq,
        channels=channels
    )

# %%
def cleanup(*objs):
    for obj in objs:
        try:
            del obj
        except Exception:
            pass
    gc.collect()

# %%
def process_edf(edf_path, save_path):
    raw = None
    data = None
    final_data = None

    try:
        raw = load_edf(edf_path)
        raw = preprocess_raw(raw)
        raw = run_ica(raw)
        raw = apply_final_crop(raw)

        data, ch_names, sfreq, n_times = extract_data(raw)

        final_data = apply_canonical_channels(
            data,
            ch_names,
            CANONICAL_CHANNELS,
            n_times
        )

        save_npz(save_path, final_data, sfreq, CANONICAL_CHANNELS)
        print("Processed:", os.path.basename(edf_path))

    except Exception as e:
        print("Failed:", edf_path, "|", e)

    finally:
        cleanup(raw, data, final_data)

# %%
def process_dataset(raw_dir, save_dir):
    os.makedirs(save_dir, exist_ok=True)

    for root, _, files in os.walk(raw_dir):
        for file in files:
            if not file.lower().endswith(".edf"):
                continue

            edf_path = os.path.join(root, file)
            save_path = os.path.join(
                save_dir,
                file.replace(".edf", ".npz")
            )

            if os.path.exists(save_path):
                print("Skipping:", file)
                continue

            process_edf(edf_path, save_path)

# %%
for patient in sorted(os.listdir(RAW_PATH)):
    patient_dir = os.path.join(RAW_PATH, patient)
    if not os.path.isdir(patient_dir):
        continue

    for file in sorted(os.listdir(patient_dir)):
        if not file.endswith(".edf"):
            continue

        edf_path = os.path.join(patient_dir, file)
        # annotation_path = os.path.join(ANN_DIR, file.replace(".edf", ".csv"))
        save_path = os.path.join(SAVE_PATH, file.replace(".edf", ".npz"))

        try:
            raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
            raw.pick("eeg")

            # seizure_times = read_siena_seizure_times(annotation_path)

            X, y, sfreq, channels = epoch_and_label(
                raw,
                seizure_times,
                epoch_len=EPOCH_LEN
            )

            save_npz(save_path, X, y, sfreq, channels)

            print("Saved:", file, "| epochs:", len(y), "| seizures:", y.sum())

        except Exception as e:
            print("Failed:", edf_path, "|", str(e))
# Out:
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Highpass cutoff frequency 15.91549 is greater than lowpass cutoff frequency 15.0, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# Failed: /workspace/raw_dataset/PN00/PN00-1.edf | name 'seizure_times' is not defined
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Highpass cutoff frequency 15.91549 is greater than lowpass cutoff frequency 15.0, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# Failed: /workspace/raw_dataset/PN00/PN00-2.edf | name 'seizure_times' is not defined
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Highpass cutoff frequency 15.91549 is greater than lowpass cutoff frequency 15.0, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# Failed: /workspace/raw_dataset/PN00/PN00-3.edf | name 'seizure_times' is not defined
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Highpass cutoff frequency 15.91549 is greater than lowpass cutoff frequency 15.0, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# Failed: /workspace/raw_dataset/PN00/PN00-4.edf | name 'seizure_times' is not defined
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Highpass cutoff frequency 15.91549 is greater than lowpass cutoff frequency 15.0, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# Failed: /workspace/raw_dataset/PN00/PN00-5.edf | name 'seizure_times' is not defined
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /tmp/ipykernel_1058/3211776597.py:15: RuntimeWarning: Highpass cutoff frequency 15.91549 is greater than lowpass cutoff frequency 15.0, setting values to 0 and Nyquist.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 15
#      12 save_path = os.path.join(SAVE_PATH, file.replace(".edf", ".npz"))
#      14 try:
# ---> 15     raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
#      16     raw.pick("eeg")
#      18     # seizure_times = read_siena_seizure_times(annotation_path)
#
# File /usr/local/lib/python3.11/dist-packages/mne/io/edf/edf.py:2011, in read_raw_edf(input_fname, eog, misc, stim_channel, exclude, infer_types, include, preload, units, encoding, exclude_after_unique, verbose)
#    1904 """Reader function for EDF and EDF+ files.
#    1905
#    1906 Parameters
#    (...)   2007 However, this reader currently sets subseconds to 0 by default.
#    2008 """
#    2009 _check_args(input_fname, preload, "edf")
# -> 2011 return RawEDF(
#    2012     input_fname=input_fname,
#    2013     eog=eog,
#    2014     misc=misc,
#    2015     stim_channel=stim_channel,
#    2016     exclude=exclude,
#    2017     infer_types=infer_types,
#    2018     preload=preload,
#    2019     include=include,
#    2020     units=units,
#    2021     encoding=encoding,
#    2022     exclude_after_unique=exclude_after_unique,
#    2023     verbose=verbose,
#    2024 )
#
# File <decorator-gen-320>:10, in __init__(self, input_fname, eog, misc, stim_channel, exclude, infer_types, preload, include, units, encoding, exclude_after_unique, verbose)
#
# File /usr/local/lib/python3.11/dist-packages/mne/io/edf/edf.py:214, in RawEDF.__init__(self, input_fname, eog, misc, stim_channel, exclude, infer_types, preload, include, units, encoding, exclude_after_unique, verbose)
#     212 # Raw attributes
#     213 last_samps = [edf_info["nsamples"] - 1]
# --> 214 super().__init__(
#     215     info,
#     216     preload,
#     217     filenames=[_path_from_fname(input_fname)],
#     218     raw_extras=[edf_info],
#     219     last_samps=last_samps,
#     220     orig_format="int",
#     221     orig_units=orig_units,
#     222     verbose=verbose,
#     223 )
#     225 # Read annotations from file and set it
#     226 if len(edf_info["tal_idx"]) > 0:
#     227     # Read TAL data exploiting the header info (no regexp)
#
# File <decorator-gen-259>:10, in __init__(self, info, preload, first_samps, last_samps, filenames, raw_extras, orig_format, dtype, buffer_size_sec, orig_units, verbose)
#
# File /usr/local/lib/python3.11/dist-packages/mne/io/base.py:306, in BaseRaw.__init__(self, info, preload, first_samps, last_samps, filenames, raw_extras, orig_format, dtype, buffer_size_sec, orig_units, verbose)
#     304 # If we have True or a string, actually do the preloading
#     305 if load_from_disk:
# --> 306     self._preload_data(preload)
#     307 self._init_kwargs = _get_argvalues()
#
# File /usr/local/lib/python3.11/dist-packages/mne/io/base.py:601, in BaseRaw._preload_data(self, preload)
#     597 t = self.times
#     598 logger.info(
#     599     f"Reading 0 ... {len(t) - 1}  =  {0.0:9.3f} ... {t[-1]:9.3f} secs..."
#     600 )
# --> 601 self._data = self._read_segment(data_buffer=data_buffer)
#     602 assert len(self._data) == self.info["nchan"]
#     603 self.preload = True
#
# File <decorator-gen-261>:12, in _read_segment(self, start, stop, sel, data_buffer, verbose)
#
# File /usr/local/lib/python3.11/dist-packages/mne/io/base.py:477, in BaseRaw._read_segment(***failed resolving arguments***)
#     475     # reindex back to original file
#     476     orig_idx = _convert_slice(self._read_picks[fi][need_idx])
# --> 477     _ReadSegmentFileProtector(self)._read_segment_file(
#     478         data[:, this_sl],
#     479         orig_idx,
#     480         fi,
#     481         int(start_file),
#     482         int(stop_file),
#     483         cals,
#     484         mult,
#     485     )
#     486     offset += n_read
#     487 return data
#
# File /usr/local/lib/python3.11/dist-packages/mne/io/base.py:2710, in _ReadSegmentFileProtector._read_segment_file(self, data, idx, fi, start, stop, cals, mult)
#    2709 def _read_segment_file(self, data, idx, fi, start, stop, cals, mult):
# -> 2710     return self.__raw.__class__._read_segment_file(
#    2711         self, data, idx, fi, start, stop, cals, mult
#    2712     )
#
# File /usr/local/lib/python3.11/dist-packages/mne/io/edf/edf.py:247, in RawEDF._read_segment_file(self, data, idx, fi, start, stop, cals, mult)
#     245 def _read_segment_file(self, data, idx, fi, start, stop, cals, mult):
#     246     """Read a chunk of raw data."""
# --> 247     return _read_segment_file(
#     248         data,
#     249         idx,
#     250         fi,
#     251         start,
#     252         stop,
#     253         self._raw_extras[fi],
#     254         self.filenames[fi]
#     255         if self._raw_extras[fi]["blob"] is None
#     256         else self._raw_extras[fi]["blob"],
#     257         cals,
#     258         mult,
#     259     )
#
# File /usr/local/lib/python3.11/dist-packages/mne/io/edf/edf.py:656, in _read_segment_file(data, idx, fi, start, stop, raw_extras, filenames, cals, mult)
#     654 fid.seek(start_offset + block_offset, 0)
#     655 # Read and reshape to (n_chunks_read, ch0_ch1_ch2_ch3...)
# --> 656 many_chunk = _read_ch(
#     657     fid, subtype, ch_offsets[-1] * n_read, dtype_byte, dtype
#     658 ).reshape(n_read, -1)
#     659 r_sidx = r_lims[ai][0]
#     660 r_eidx = buf_len * (n_read - 1) + r_lims[ai + n_read - 1][1]
#
# File /usr/local/lib/python3.11/dist-packages/mne/io/edf/edf.py:604, in _read_ch(fid, subtype, samp, dtype_byte, dtype)
#     600     ch_data[ch_data >= (1 << 23)] -= 1 << 24
#     602 # GDF data and EDF data
#     603 else:
# --> 604     ch_data = read_from_file_or_buffer(fid, dtype=dtype, count=samp)
#     606 return ch_data
#
# File /usr/local/lib/python3.11/dist-packages/mne/fixes.py:761, in read_from_file_or_buffer(file, dtype, count)
#     749 """numpy.fromfile() wrapper, handling io.BytesIO file-like streams.
#     750
#     751 Numpy requires open files to be actual files on disk, i.e., must support
#    (...)    758 See https://github.com/numpy/numpy/issues/2230#issuecomment-949795210
#     759 """
#     760 try:
# --> 761     return np.fromfile(file, dtype=dtype, count=count)
#     762 except io.UnsupportedOperation as e:
#     763     if not (e.args and e.args[0] == "fileno" and isinstance(file, io.IOBase)):
#
# KeyboardInterrupt:

# %% [markdown]
# - saved as npz as its compressed stack of numpy arrays compatible with dl models

# %% [markdown]
# CNN
# -  input layer
# - 1 d convolution layer - kernel slides over the signal to find features
# - activation layer - make the features non-linear
# - batch normalisation - normalise feature maps - better generalisation
# - pooling layer - samples temporal dimensions - robust to noise and change in temporal cahnges

# %% [markdown]
# - bilstm focuses on temporal features
# - memory cells - 3 gates
# - forget, input, cell state
# - forget removes noise
# - input - stores features
# - cell state - accumalte all features
# - forward - from past to present
# - backward - present to past

# %% [markdown]
# - attention mechanism
# - higher wts to all seizure features
