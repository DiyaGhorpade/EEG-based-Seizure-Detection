# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p "/content/drive/MyDrive/SIENA_EEG"

# %%
# !curl "https://awscli.amazonaws.com/awscli-exe-linux-x86_64.zip" -o "awscliv2.zip"
# !unzip awscliv2.zip
# !sudo ./aws/install
# !aws --version
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: aws/dist/awscli/examples/greengrass/get-connector-definition-version.rst
#   inflating: aws/dist/awscli/examples/greengrass/create-function-definition.rst
#   inflating: aws/dist/awscli/examples/greengrass/list-function-definitions.rst
#   inflating: aws/dist/awscli/examples/greengrass/delete-core-definition.rst
#   inflating: aws/dist/awscli/examples/greengrass/start-bulk-deployment.rst
#   inflating: aws/dist/awscli/examples/greengrass/create-resource-definition-version.rst
#   inflating: aws/dist/awscli/examples/greengrass/get-subscription-definition-version.rst
#   inflating: aws/dist/awscli/examples/greengrass/get-core-definition-version.rst
#   inflating: aws/dist/awscli/examples/greengrass/get-logger-definition-version.rst
#   inflating: aws/dist/awscli/examples/greengrass/stop-bulk-deployment.rst
#   inflating: aws/dist/awscli/examples/greengrass/get-group.rst
# ...

# %%
# !aws s3 ls --no-sign-request s3://physionet-open/siena-scalp-eeg/1.0.0/
# Out:
#                            PRE PN00/
#                            PRE PN01/
#                            PRE PN03/
#                            PRE PN05/
#                            PRE PN06/
#                            PRE PN07/
#                            PRE PN09/
#                            PRE PN10/
#                            PRE PN11/
#                            PRE PN12/
#                            PRE PN13/
#                            PRE PN14/
#                            PRE PN16/
#                            PRE PN17/
# 2024-03-09 04:43:10      14842 LICENSE.txt
# 2024-03-09 04:43:10        667 RECORDS
# 2024-03-09 04:43:10       4866 SHA256SUMS.txt
# 2024-03-09 04:43:10        563 subject_info.csv

# %%
# !aws s3 sync --no-sign-request s3://physionet-open/siena-scalp-eeg/1.0.0/ /content/drive/MyDrive/SIENA_EEG
# Out:
# download: s3://physionet-open/siena-scalp-eeg/1.0.0/LICENSE.txt to drive/MyDrive/SIENA_EEG/LICENSE.txt
# download: s3://physionet-open/siena-scalp-eeg/1.0.0/PN03/Seizures-list-PN03.txt to drive/MyDrive/SIENA_EEG/PN03/Seizures-list-PN03.txt
# download: s3://physionet-open/siena-scalp-eeg/1.0.0/PN00/Seizures-list-PN00.txt to drive/MyDrive/SIENA_EEG/PN00/Seizures-list-PN00.txt
# download: s3://physionet-open/siena-scalp-eeg/1.0.0/PN00/PN00-3.edf to drive/MyDrive/SIENA_EEG/PN00/PN00-3.edf
# download: s3://physionet-open/siena-scalp-eeg/1.0.0/PN00/PN00-4.edf to drive/MyDrive/SIENA_EEG/PN00/PN00-4.edf
# download: s3://physionet-open/siena-scalp-eeg/1.0.0/PN00/PN00-5.edf to drive/MyDrive/SIENA_EEG/PN00/PN00-5.edf
# download: s3://physionet-open/siena-scalp-eeg/1.0.0/PN00/PN00-1.edf to drive/MyDrive/SIENA_EEG/PN00/PN00-1.edf
# download: s3://physionet-open/siena-scalp-eeg/1.0.0/PN00/PN00-2.edf to drive/MyDrive/SIENA_EEG/PN00/PN00-2.edf
# ...
